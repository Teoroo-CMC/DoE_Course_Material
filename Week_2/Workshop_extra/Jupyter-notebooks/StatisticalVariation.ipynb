# %% [markdown]
# <a href="https://colab.research.google.com/github/peterbmob/DoEDHMA/blob/main/DataHandling/StatistialVAriation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Statistical Variation
# To support claims about populations (or distributions), we use statistics.

# %%
import seaborn as sns
import random as random
# %matplotlib inline

# %%
random.seed(42)
values = [random.randrange(1,1001,1) for _ in range(10000)]
values[0:10]
# Out:
# [655, 115, 26, 760, 282, 251, 229, 143, 755, 105]

# %%
sns.stripplot(x=values, jitter=True, alpha=0.2)
# Out:
# <AxesSubplot:>

# %%
sparse_values = [random.randrange(1,1001) for _ in range (200)]
sns.stripplot(x=sparse_values, jitter=True)
# Out:
# <AxesSubplot:>
